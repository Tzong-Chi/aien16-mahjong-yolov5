# %%
# clone repo
# !git clone https://github.com/ultralytics/yolov5  
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow


import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 11668, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 11668 (delta 1), reused 6 (delta 1), pack-reused 11662
# Receiving objects: 100% (11668/11668), 11.36 MiB | 26.37 MiB/s, done.
# Resolving deltas: 100% (8060/8060), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.3 MB/s
#      |████████████████████████████████| 67 kB 3.1 MB/s
#      |████████████████████████████████| 138 kB 27.4 MB/s
#      |████████████████████████████████| 1.1 MB 48.2 MB/s
#      |████████████████████████████████| 145 kB 47.2 MB/s
#      |████████████████████████████████| 178 kB 53.8 MB/s
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from roboflow import Roboflow
#call roboflow api 把資料抓下來
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
os.environ["DATASET_DIRECTORY"] = "/content/datasets"
rf = Roboflow(api_key="McKZu0hrOCPqPDI7t2J0")
project = rf.workspace("calvin-hsu").project("mahjong-t25l9")
dataset = project.version(3).download("yolov5")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/-Mahjong-3 in yolov5pytorch:: 100%|██████████| 6594/6594 [00:06<00:00, 994.68it/s]

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
# 用 train.py 訓練
# optimizer 選擇優化器  
# weights 權重
# !python train.py --img 416 --batch-size 32 --data {dataset.location}/data.yaml --epochs 200 --weights yolov5s.pt --optimizer AdamW --cfg ./models/yolov5s.yaml --cache
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/content/datasets/-Mahjong-3/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=32, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=AdamW, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-54-ga2d617e torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
import torch
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (Tesla K80)

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !zip -r /content/yolov5.zip /content/yolov5
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/train.py (deflated 69%)
#   adding: content/yolov5/utils/ (stored 0%)
#   adding: content/yolov5/utils/aws/ (stored 0%)
#   adding: content/yolov5/utils/aws/userdata.sh (deflated 47%)
#   adding: content/yolov5/utils/aws/resume.py (deflated 46%)
#   adding: content/yolov5/utils/aws/mime.sh (deflated 46%)
#   adding: content/yolov5/utils/aws/__init__.py (stored 0%)
#   adding: content/yolov5/utils/google_app_engine/ (stored 0%)
#   adding: content/yolov5/utils/google_app_engine/Dockerfile (deflated 47%)
#   adding: content/yolov5/utils/google_app_engine/additional_requirements.txt (deflated 10%)
#   adding: content/yolov5/utils/google_app_engine/app.yaml (deflated 26%)
#   adding: content/yolov5/utils/general.py (deflated 65%)
#   adding: content/yolov5/utils/benchmarks.py (deflated 62%)
#   adding: content/yolov5/utils/torch_utils.py (deflated 62%)
#   adding: content/yolov5/utils/loggers/ (stored 0%)
# ...

# %%
# !unzip yolov5.zip
# Out:
# Archive:  yolov5.zip
#    creating: content/yolov5/
#    creating: content/yolov5/__pycache__/
#   inflating: content/yolov5/__pycache__/val.cpython-37.pyc
#   inflating: content/yolov5/requirements.txt
#   inflating: content/yolov5/train.py
#   inflating: content/yolov5/detect.py
#   inflating: content/yolov5/val.py
#   inflating: content/yolov5/CONTRIBUTING.md
#   inflating: content/yolov5/hubconf.py
#   inflating: content/yolov5/setup.cfg
#    creating: content/yolov5/data/
#    creating: content/yolov5/data/hyps/
#   inflating: content/yolov5/data/hyps/hyp.scratch-high.yaml
#   inflating: content/yolov5/data/hyps/hyp.VOC.yaml
#   inflating: content/yolov5/data/hyps/hyp.Objects365.yaml
#   inflating: content/yolov5/data/hyps/hyp.scratch-med.yaml
#   inflating: content/yolov5/data/hyps/hyp.scratch-low.yaml
#   inflating: content/yolov5/data/VisDrone.yaml
#   inflating: content/yolov5/data/coco.yaml
#    creating: content/yolov5/data/images/
# ...

# %%
# %cd /content/content/yolov5/
# Out:
# /content/content/yolov5

# %%
# !rm -rf /content/datasets

# %%
# %pip install -q roboflow
import torch
import os
from roboflow import Roboflow
# 不同版本的dataset
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
os.environ["DATASET_DIRECTORY"] = "/content/datasets"
rf = Roboflow(api_key="McKZu0hrOCPqPDI7t2J0")
project = rf.workspace("calvin-hsu").project("mahjong2-97a3a")
dataset = project.version(1).download("yolov5")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/Mahjong2-1 in yolov5pytorch:: 100%|██████████| 8998/8998 [00:07<00:00, 1131.35it/s]

# %%
# !python train.py --img 416 --batch-size 32 --data {dataset.location}/data.yaml --epochs 100 --weights /content/yolov5/runs/train/exp2/weights/best.pt --optimizer Adam --cfg ./models/yolov5s.yaml --cache
# Out:
# train: weights=/content/yolov5/runs/train/exp2/weights/best.pt, cfg=./models/yolov5s.yaml, data=/content/datasets/Mahjong2-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-37-g3f634d4 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !pip install tensorflowjs
# 匯成tensorflowjs的模型
# !python export.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --include tfjs

# %%
# !zip -r /content/best_web_model_Adam.zip /content/yolov5/runs/train/exp3/weights/best_web_model

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --img 416 --conf 0.3 --source /content/datasets/Mahjong2-1/test/images --save-txt
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
# !zip -r /content/adam.zip /content/yolov5
